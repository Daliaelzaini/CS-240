# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import thinkstats2
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

# %%
data = pd.read_csv("Salaries.csv")
data
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# 5        1985    ATL   NL  chambch01    800000
# 6        1985    ATL   NL  dedmoje01    150000
# 7        1985    ATL   NL  forstte01    483333
# 8        1985    ATL   NL  garbege01    772000
# 9        1985    ATL   NL  harpete01    250000
# 10       1985    ATL   NL  hornebo01   1500000
# 11       1985    ATL   NL  hubbagl01    455000
# 12       1985    ATL   NL  mahleri01    407500
# 13       1985    ATL   NL  mcmurcr01    275000
# 14       1985    ATL   NL  mumphje01    775000
# 15       1985    ATL   NL  murphda05   1625000
# 16       1985    ATL   NL  oberkke01    616667
# 17       1985    ATL   NL  perezpa01    450000
# 18       1985    ATL   NL  perryge01    120000
# ...

# %%
h2 = main.test_time_gpa((time, gpa))
print np.mean(time)
print np.mean(gpa)
print h2.TestStatistic((time, gpa))
h2.PValue(iters=10000)
# Out:
#  506.722689076
# 3.02319327731
# 0.261269244021
# 0.0037

# %%
slope, intercept = np.polyfit(yearID,salary,1)
print "slope: ", slope, "intercept: ", intercept
pointsLine = [intercept+slope*x for x in yearID]
plt.figure()
plt.plot(yearID,salary, "o")
plt.plot(yearID, pointsLine, "--")
plt.show()
# Out:
# slope:  -0.000560943554821 intercept:  3.30743610383
# <img src="data:image/png;base64,...">

# %%
residuals = [y- (slope*x + intercept) for x, y in zip(yearID,salary)]
res_plt = sorted(zip(time, residuals))
t2 = [x for x,y in res_plt]
r2 = [y for x,y in res_plt]
plt.figure()
plt.plot(t2, r2,  'o-')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2a68b3ee7aa7> in <module>()
# ----> 1 residuals = [y- (slope*x + intercept) for x, y in zip(yearID,salary)]
#       2 res_plt = sorted(zip(time, residuals))
#       3 t2 = [x for x,y in res_plt]
#       4 r2 = [y for x,y in res_plt]
#       5 plt.figure()
#
# NameError: name 'yearID' is not defined

# %%
log_gpa = [np.log(x) for x in yearID]
slope_log, intercept_log = np.polyfit(yearID,log_yearID,1)
print "line fit for yearID and log(yearID)"
print "slope: ", slope_log, "intercept: ", intercept_log
pointsLineLog = [intercept_log+slope_log*x for x in yearID]
plt.figure()
plt.plot(yearID, log_yearID, "o")
plt.plot(yearID, pointsLineLog, '--')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-44ab6020701e> in <module>()
# ----> 1 log_gpa = [np.log(x) for x in yearID]
#       2 slope_log, intercept_log = np.polyfit(yearID,log_yearID,1)
#       3 print "line fit for yearID and log(yearID)"
#       4 print "slope: ", slope_log, "intercept: ", intercept_log
#       5 pointsLineLog = [intercept_log+slope_log*x for x in yearID]
#
# NameError: name 'yearID' is not defined

# %%
formula='salary ~ salary + IgId + yearID'
data_dict = {"salary":salary, "salary":salary, "IgID":IgID, "yearID":yearID}
model = smf.poisson(formula, data=data_dict).fit()
if salary = 8700

print "predicted salary for 870000  NL team who was born at 1985: ", model.predict({"salary": 8700, "IgID":'NL', "yearID":1985})
# Out:
#   File "<ipython-input-1-01ad81145ce1>", line 4
#     if salary = 8700
#               ^
# SyntaxError: invalid syntax

# %%
print "slope for yearID and salary is: ", slope

print "\n\nMultiple regression model:"
modelMR = smf.ols('salary ~ salary + IgId + yearID', data=data_dict).fit()
print modelMR.summary()
modelMR.predict({"salary":550000, "yearID":1985, "IgID":'NL'})
# Out:
#  slope for yearID and salary is:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-30ec403b52e4> in <module>()
# ----> 1 print "slope for yearID and salary is: ", slope
#       2
#       3 print "\n\nMultiple regression model:"
#       4 modelMR = smf.ols('salary ~ salary + IgId + yearID', data=data_dict).fit()
#       5 print modelMR.summary()
#
# NameError: name 'slope' is not defined
